# %%
import quandl
import pandas as pd
import numpy as np



quandl.ApiConfig.api_key = 'JxpNhfJF_ssPsQs_7fJu'

# %%
FZips = pd.read_csv('input/Fulton Zips.csv',header=0)

# %%
FZips
# Out:
#     Zip Codes
# 0       30004
# 1       30005
# 2       30009
# 3       30022
# 4       30075
# 5       30076
# 6       30097
# 7       30213
# 8       30268
# 9       30291
# 10      30303
# 11      30305
# 12      30306
# 13      30308
# 14      30309
# 15      30310
# 16      30311
# 17      30312
# 18      30313
# 19      30314
# 20      30315
# 21      30315
# 22      30318
# 23      30324
# 24      30327
# 25      30328
# 26      30331
# 27      30336
# 28      30337
# 29      30342
# 30      30344
# 31      30349
# 32      30350
# 33      30354

# %%
InputCodes = pd.read_csv('input/Clean Zillow Codes.csv',header=0)

# %%
Codes=InputCodes["Code"]
Category=InputCodes["Name"]

# %%
# Median Rental Price Per Square Foot
# ONLY RUN FOR RENTAL INFO   
Codes=["_MRPF1B",
"_MRPF2B",
"_MRPF3B",
"_MRPF4B",
"_MRPF5B",
"_MRPFAH",
"_MRPFMF",
"_MRPFSF",
"_MRPFST"]

# %%
# Median Listing Price Per Square Foot
# ONLY RUN WHEN LOOKING AT LISTING PRICE INFO
Codes=["_MLPF1B",
"_MLPF2B",
"_MLPF3B",
"_MLPF4B",
"_MLPF5B",
"_MLPFAH",
"_MLPFMF",
"_MLPFSF",
"_MLPFST"]

# %%
# Category Descriptors
Category=["One Bedroom",
"Two Bedrooms",
"Three Bedrooms",
"Four Bedrooms",
"Five or More Bedrooms",          
"All Homes",
"Multi-Family Residence",
"Single-Family Residence",
"Studio"]

# %%
Category
# Out:
# ['One Bedroom',
#  'Two Bedrooms',
#  'Three Bedrooms',
#  'Four Bedrooms',
#  'Five or More Bedrooms',
#  'All Homes',
#  'Multi-Family Residence',
#  'Single-Family Residence',
#  'Studio']

# %%
#TEST ONLY

ZC="30004"

for item in Codes:
    this_code="ZILLOW/Z"+ZC+item
    #temp = quandl.get(this_code)
    #final = temp['Value'].size
    #test = temp.Value[temp['Value'].size-1]
    #test
    print(this_code)
# Out:
# ZILLOW/Z30004_MRPF1B
# ZILLOW/Z30004_MRPF2B
# ZILLOW/Z30004_MRPF3B
# ZILLOW/Z30004_MRPF4B
# ZILLOW/Z30004_MRPF5B
# ZILLOW/Z30004_MRPFAH
# ZILLOW/Z30004_MRPFMF
# ZILLOW/Z30004_MRPFSF
# ZILLOW/Z30004_MRPFST

# %%
ZipList=FZips["Zip Codes"]
ZipList
# Out:
# 0     30004
# 1     30005
# 2     30009
# 3     30022
# 4     30075
# 5     30076
# 6     30097
# 7     30213
# 8     30268
# 9     30291
# 10    30303
# 11    30305
# 12    30306
# 13    30308
# 14    30309
# 15    30310
# 16    30311
# 17    30312
# 18    30313
# 19    30314
# 20    30315
# 21    30315
# 22    30318
# 23    30324
# 24    30327
# 25    30328
# 26    30331
# 27    30336
# 28    30337
# 29    30342
# 30    30344
# 31    30349
# 32    30350
# 33    30354
# Name: Zip Codes, dtype: int64

# %%
#ZipList=["30004","30005","30009"]

df=pd.DataFrame()

for ZC in ZipList:
    #loop through and pull the last line from each API Call
    # ******* Does the API Calls
    stats=[]
    for item in Codes:
        this_code="ZILLOW/Z"+str(ZC)+item
        try:
            temp = quandl.get(this_code)
            final = temp['Value'].size
            test = temp.Value[temp['Value'].size-1]
        except:
            test = np.nan
        stats.append(test)
        #print(this_code)
    df[ZC]=stats

# %%
df
# Out:
#            30004        30005        30009        30022        30075  \
# 0            NaN          NaN          NaN          NaN          NaN
# 1            NaN          NaN          NaN          NaN          NaN
# 2            NaN          NaN          NaN          NaN          NaN
# 3            NaN          NaN          NaN          NaN          NaN
# 4            NaN          NaN          NaN          NaN          NaN
# ..           ...          ...          ...          ...          ...
# 132  1617.000000  1692.000000  1663.000000  1637.000000  1787.000000
# 133     0.958000     0.878000     1.036000     0.930000     0.972000
# 134  1478.000000  1560.000000  1518.000000  1473.000000  1409.000000
# 135  2459.000000  2520.000000  2056.000000  2487.000000  2457.000000
# 136     0.019457     0.089711     0.049139     0.004287     0.008979
#
#           30076        30097        30213        30268        30291  ...  \
# ...

# %%
df2=df
df2['Titles']=Category
df2.set_index('Titles',inplace=True)
df2
# Out:
#                                                          30004        30005  \
# Titles
# Age of Inventory (Public)                                  NaN          NaN
# Buyer Seller Index Cross MSA                               NaN          NaN
# Buyer Seller Index Cross Time MSA                          NaN          NaN
# Days on Zillow MSA                                         NaN          NaN
# Days on Zillow (Public)                                    NaN          NaN
# ...                                                        ...          ...
# Zillow Rental Index - All Homes Plus Multi-Family  1617.000000  1692.000000
# Zillow Rental Index Per Square Foot - All Homes       0.958000     0.878000
# Zillow Rental Index - Multi-Family Residence       1478.000000  1560.000000
# Zillow Rental Index - Single-Family Residence      2459.000000  2520.000000
# ZRI - Top Tier YOY                                    0.019457     0.089711
#
# ...

# %%
#Rental Price Per Square Foot
#df2.to_csv("output/FultonRental.csv", encoding="utf-8", index=True, header=True)

# %%
#Listing Price Per Square Foot
#df2.to_csv("output/FultonListings.csv", encoding="utf-8", index=True, header=True)

# %%
#Set of interesting categories
df2.to_csv("output/Fulton All Categories.csv", encoding="utf-8", index=True, header=True)
